# %% [markdown]
# <H3 align='center'> Assignment Python 3 : <br> Bank Marketing Dataset</H3>

# %% [markdown]
# <div style="text-align:center">
#     <img src="https://east.vc/wp-content/uploads/2020/01/hacktiv8-1.png" alt="Logo Hacktiv8" />
# </div>

# %% [markdown]
# <div style="text-align:center">
#     <u> OLEH : </u><br></br>
#     <table style="border:none; margin: 0 auto; text-align:left;">
#         <tr>
#             <td style="border: none;">Nama</td>
#             <td style="border: none;">: Resti Apriliyanti</td>
#         </tr>
#         <tr>
#             <td style="border: none;">No. Peserta</td>
#             <td style="border: none;">: PYTN-KS20-011</td>
#         </tr>
#         <tr>
#             <td style="border: none;">Program</td>
#             <td style="border: none;">: Python for Data Science</td>
#         </tr>
#     </table>
# </div>
# <br></br>

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Introduction
# <p style="text-align: justify; font-size: 14px;">
#     Kampanye pemasaran yang dilakukan oleh lembaga perbankan Portugis berfokus pada panggilan telepon untuk mempromosikan produk deposito berjangka kepada calon nasabah. Data yang dikumpulkan mencakup periode dari Mei 2008 hingga November 2010 dan mencakup beberapa kumpulan data, baik yang lengkap maupun yang diambil secara acak sebesar 10% dari kumpulan data lengkap.
# </p>
#
# <p style="text-align: justify; font-size: 14px;">
#     Pada dasarnya, lembaga perbankan ini ingin meningkatkan efektivitas kampanye pemasaran mereka dengan memahami faktor-faktor yang memengaruhi keputusan nasabah untuk berlangganan deposito berjangka setelah menerima panggilan telepon. Tujuan utama adalah membangun model klasifikasi yang dapat memprediksi apakah seorang nasabah akan berlangganan ('ya') atau tidak ('tidak').
# </p>

# %% [markdown]
# ### Rumusan Masalah
# <p style="text-align: justify; font-size: 14px;">
#     <ol style="text-align: justify; font-size: 14px;">
#         <li>
#             Berapa Perbandingan Jumlah Klien yang Berlangganan Deposito Berjangka?
#         <li>
#             Di usia berapa klien rata-rata bank yang berlangganan?
#         <li>
#             Pada bulan berapa panggilan nomor terbanyak pada setahun terakhir?
#         <li>
#             Klien dengan pendidikan apa yang mendominasi sebagai pelanggan?
#     </ol>
# </p>

# %% [markdown]
# ### Dataset
# <p style="text-align: justify; font-size: 14px;">
#     Project ini menggunakan 4 dataset yaitu :
#     <li> bank-additional-full.csv
#     <li> bank-additional.csv
#     <li> bank-ful.csv
#     <li> bank.csv
#     yang dapat diunduh pada link berikut :
# </p>
# <div style="text-align:center; font-size:14px">
# <p>
#     Dataset : <a href=https://archive.ics.uci.edu/dataset/222/bank+marketing>Bank Marketing</a>
# </p>
#     <table style="border:none; margin: 0 auto; text-align:left;">
#         <tr>
#             <td style="text-align:center"><b>No.</b></td>
#             <td style="text-align:center"><b>Variabel</b></td>
#             <td style="text-align:center"><b>Keterangan</b></td>
#         </tr>
#         <tr>
#             <td style="text-align:center">1. </td>
#             <td>age</td>
#             <td>usia (numerik)</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">2. </td>
#             <td>job</td>
#             <td>jenis pekerjaan (kategorikal: "admin.","tidak diketahui","pengangguran","manajemen","pembantu rumah tangga","pengusaha"," pelajar", "kerah biru", "wiraswasta", "pensiun", "teknisi", "jasa").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">3. </td>
#             <td>marital</td>
#             <td>status perkawinan (kategorikal: "menikah", "bercerai", "lajang"; catatan: "bercerai" berarti bercerai atau duda).</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">4. </td>
#             <td>education</td>
#             <td>pendidikan (kategoris: "tidak diketahui", "sekunder", "primer", "tersier").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">5. </td>
#             <td>default</td>
#             <td>apakah kreditnya default? (biner: "ya", "tidak").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">6. </td>
#             <td>balance</td>
#             <td>saldo rata-rata tahunan, dalam euro (angka).</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">7. </td>
#             <td>housing</td>
#             <td>memiliki pinjaman perumahan? (biner: "ya", "tidak").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">8. </td>
#             <td>loan</td>
#             <td>memiliki pinjaman pribadi? (biner: "ya","tidak").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">9. </td>
#             <td>contact</td>
#             <td>jenis komunikasi kontak (kategorikal: "tidak diketahui", "telepon", "seluler").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">10. </td>
#             <td>day</td>
#             <td>kontak terakhir hari dalam sebulan (numerik).</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">11. </td>
#             <td>month</td>
#             <td>bulan kontak terakhir dalam setahun (kategoris: "jan", "feb", "mar", ..., "nov", "dec").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">12. </td>
#             <td>duration</td>
#             <td>durasi kontak terakhir , dalam detik (numerik).</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">13. </td>
#             <td>campaign</td>
#             <td>jumlah kontak yang dilakukan selama kampanye ini dan untuk klien ini (numerik, termasuk kontak terakhir).</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">14. </td>
#             <td>pdays</td>
#             <td>jumlah hari yang berlalu setelah klien terakhir dihubungi dari a kampanye sebelumnya (angka, -1 berarti klien belum pernah dihubungi sebelumnya).</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">15. </td>
#             <td>previous</td>
#             <td>jumlah kontak yang dilakukan sebelum kampanye ini dan untuk klien ini (angka) .</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">16. </td>
#             <td>poutcome</td>
#             <td>hasil kampanye pemasaran sebelumnya (kategorikal: "tidak diketahui"," other","failure","success").</td>
#         </tr>
#         <tr>
#             <td style="text-align:center">17. </td>
#             <td>y</td>
#             <td>apakah klien sudah berlangganan deposito berjangka? (biner: "ya", "tidak").</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ## Python Implementation

# %% [markdown]
# ### 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# Visualization
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Modelling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

# Ignore warning
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)

# %% [markdown]
# ### 2. Data Loading

# %%
df = pd.read_csv('dataset/bank-additional-full.csv', sep=';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
# Mengecek dimensi dataset
df.shape
# Out:
# (41188, 21)

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# #### 3.1 Mengecek Tipe Data Variabel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# Berdasarkan data, semua tipe data sudah sesuai sehingga tidak perlu dilakikan konversi tipe data

# %% [markdown]
# #### 3.2 Mengecek *Missing Value* pada Data

# %%
# Mengecek Nilai Null
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# Berdasarkan data, diketahui bahwa tidak ada data yang memiliki nilai null

# %% [markdown]
# #### 3.3 Menghapus Kolom yang tidak Diperlukan

# %%
# Mengecek Kolom pada Dataset
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
# kolom yang akan dihapus
hapus = ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# Menghapus kolom yang tidak digunakan dari DataFrame
df = df.drop(columns=hapus)

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# #### 3.4 Menghapus Data Duplikat

# %%
# Mengecek jumlah file duplikat
df.duplicated().sum()
# Out:
# 13

# %%
# Menampilkan baris data yang merupakan duplikat
df[df.duplicated()]
# Out:
#        age          job   marital            education  default housing loan  \
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20216   55     services   married          high.school  unknown      no   no
# 20534   41   technician   married  professional.course       no     yes   no
# 25217   39       admin.   married    university.degree       no      no   no
# 28477   24     services    single          high.school       no     yes   no
# 32516   35       admin.   married    university.degree       no     yes   no
# 33296   36  blue-collar   married             basic.9y       no      no   no
# ...

# %% [markdown]
# Berdasarkan data, ada 13 baris data yang merupakan duplikat dari data lainnya sehingga perlu dihapus dari dataset

# %%
# Menghapus data duplikat
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 4. Data Exploration

# %% [markdown]
# #### 4.1 Mengekplorasi Nilai Unik Setiap Kolom

# %%
for col in df.columns:
    print("UNIQUE VALUES FOR ",col)
    print("="*20)
    print(df[col].unique())
    print("="*20)
# Out:
# UNIQUE VALUES FOR  age
# ...
# [56 57 37 40 45 59 41 24 25 29 35 54 46 50 39 30 55 49 34 52 58 32 38 44
#  42 60 53 47 51 48 33 31 43 36 28 27 26 22 23 20 21 61 19 18 70 66 76 67
#  73 88 95 77 68 75 63 80 62 65 72 82 64 71 69 78 85 79 83 81 74 17 87 91
#  86 98 94 84 92 89]
# ...
# UNIQUE VALUES FOR  job
# ...
# ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
# ...
# UNIQUE VALUES FOR  marital
# ...
# ['married' 'single' 'divorced' 'unknown']
# ...
# UNIQUE VALUES FOR  education
# ...
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
# ...
# UNIQUE VALUES FOR  default
# ...
# ['no' 'unknown' 'yes']
# ...
# UNIQUE VALUES FOR  housing
# ...
# ['no' 'yes' 'unknown']
# ...
# UNIQUE VALUES FOR  loan
# ...
# ['no' 'yes' 'unknown']
# ...
# UNIQUE VALUES FOR  contact
# ...
# ['telephone' 'cellular']
# ...
# UNIQUE VALUES FOR  month
# ...
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# ...

# %% [markdown]
# #### 4.2 Mendeskripsikan Data Bertipe Kategori

# %%
print("Describe categorical data:")
df.describe(exclude = "number")
# Out:
# Describe categorical data:
#            job  marital          education default housing   loan   contact  \
# count    41175    41175              41175   41175   41175  41175     41175
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10419    24920              12164   32576   21571  33937     26134
#
#         month day_of_week     poutcome      y
# count   41175       41175        41175  41175
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13766        8618        35550  36536

# %% [markdown]
# #### 4.3 Mendeskripsikan Data Bertipe Numerik

# %%
print("Describe numerical data:")
df.describe().T
# Out:
# Describe numerical data:
#             count        mean         std   min    25%    50%    75%     max
# age       41175.0   40.023898   10.420788  17.0   32.0   38.0   47.0    98.0
# duration  41175.0  258.318421  259.307930   0.0  102.0  180.0  319.0  4918.0
# campaign  41175.0    2.567917    2.770341   1.0    1.0    2.0    3.0    56.0
# pdays     41175.0  962.463922  186.939285   0.0  999.0  999.0  999.0   999.0
# previous  41175.0    0.173018    0.494970   0.0    0.0    0.0    0.0     7.0

# %% [markdown]
# <b>Insight : </b> Berdasarkan output heatmap di atas, 'timestamp' dan 'month' memiliki korelasi yang cukup tinggi yaitu 0.77.

# %% [markdown]
# ### 5. Data Visualization

# %% [markdown]
# 5.1 Perbandingan Jumlah Klien yang Berlangganan Deposito Berjangka

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='y')

# Menambahkan jumlah di atas setiap bar
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom')

plt.xticks(ticks=range(2), labels=['Tidak', 'Ya'])
plt.xlabel('Berlangganan Deposito Berjangka?')
plt.ylabel('Jumlah Klien')
plt.title('Perbandingan Jumlah Klien yang Berlangganan Deposito')
plt.show()

# %% [markdown]
# <b>Insight : </b> Berdasarkan bar chart, diketahui bahwa 4639 klien yang berlangganan deposito dan ada sekitar 36536 klien yang tidak berlangganan deposito.

# %% [markdown]
# 5.2 Distribusi Data Klien yang Berlangganan atau Tidak Berdasarkan Usia

# %%
# Interval dan pengelompokan usia
interval = 5
max_age = df['age'].max()
bins = list(range(0, max_age + interval, interval))
labels = [f'{i}-{i+interval-1}' for i in bins[:-1]]

# Menambahkan kolom 'age_group'
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

# Membuat plot
plot = sns.catplot(data=df, x='age_group', kind='count', order=labels)
plot.set_xticklabels(rotation=90)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_4628\3448331116.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)
# c:\Users\Acer\anaconda3\envs\snowflakes\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# <b>Insight : </b> Berdasarkan grafik, diketahui bahwa klien dari bank banyak dari kalangan usia 30 - 34 tahun

# %% [markdown]
# 5.3 Perbandingan Jumlah Panggilan Setahun Terakhir

# %%
df.month.unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'mar', 'apr',
#        'sep'], dtype=object)

# %%
# menyiapkan data
mar = df.loc[df['month'] == 'mar'].count()[0]
apr = df.loc[df['month'] == 'apr'].count()[0]
may = df.loc[df['month'] == 'may'].count()[0]
jun = df.loc[df['month'] == 'jun'].count()[0]
jul = df.loc[df['month'] == 'jul'].count()[0]
aug = df.loc[df['month'] == 'aug'].count()[0]
sep = df.loc[df['month'] == 'sep'].count()[0]
octo = df.loc[df['month'] == 'oct'].count()[0]
nov = df.loc[df['month'] == 'nov'].count()[0]
dec = df.loc[df['month'] == 'dec'].count()[0]
data_month = [mar, apr, may, jun, jul, aug, sep, octo, nov, dec]

# memberikan label dan setting data
labels = ['Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Octo', 'Nov', 'Dec']
colors = ["gold", "lightblue", "coral", "yellowgreen", "maroon", "lightcoral", "lightskyblue", "lightgreen", "pink", "cyan"]
explode_sequence = ('0.1,' * 10).split(',')
explode_sequence = [float(item) for item in explode_sequence if item !=""]

#membuat pie plot 
plt.pie(data_month, labels=labels, colors=colors, radius=2, autopct='%1.1f%%', explode=explode_sequence,
        shadow=True, startangle=90, pctdistance=0.7)
plt.title("Persentase Jumlah Panggilan Setahun terakhir", y=1.5)
plt.show()

# %% [markdown]
# <b>Insight : </b> Berdasarkan chart, tiga besar nomor panggilan terbanyak dilakukan pada bulan Mei dengan 33,4%, Juli dengan 17,4%, dan Agustus dengan 15%.

# %% [markdown]
# 5.4 Distribusi Data Klien yang Berlangganan atau Tidak Berdasarkan Pendidikan Terakhir

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='education', hue='y', order=['illiterate', 'basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'professional.course', 'university.degree'])

# Menambahkan jumlah di atas setiap bar
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.xlabel('Pendidikan Terakhir')
plt.ylabel('Jumlah')
plt.title('Distribusi Data Klien yang Berlangganan atau Tidak Berdasarkan Pendidikan Terakhir')
plt.xticks(rotation=45)
plt.legend(title='Klien', labels=['No', 'Yes'], loc='upper left')
plt.show()

# %% [markdown]
# <b> Insight : </b> Berdasarkan data di atas, data bahwa klien di dominasi oleh orang-orang dengan pendidikan terakhir di universitas (sarjana). Ada 1669 klien yang berlangganan deposito memiliki pendidikan terakhir di universitas (sarjana), kemudian diurutan ke dua diikuti oleh klien dengan pendidikan terakhir di SMA atau high school dengan jumlah 1031 klien.

# %% [markdown]
# ### 6. Data Preprocessing

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome   y  \
# 0   may         mon       261         1    999         0  nonexistent  no
# 1   may         mon       149         1    999         0  nonexistent  no
# 2   may         mon       226         1    999         0  nonexistent  no
# 3   may         mon       151         1    999         0  nonexistent  no
# 4   may         mon       307         1    999         0  nonexistent  no
#
#   age_group
# 0     55-59
# 1     55-59
# 2     35-39
# 3     35-39
# 4     55-59

# %% [markdown]
# #### 6.1 Encoding Data

# %%
#Melakukan encoding pada atribut yang memiliki tipe data Object.
categorical_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y', 'age_group']

# Melakukan label encoding
label_encoder = LabelEncoder()
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# Menampilkan hasil
df.head()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_4628\212843765.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_4628\212843765.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_4628\212843765.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# #### 6.2 Spliting Data

# %%
# Memisahkan fitur dan target
X = df.drop('y', axis=1)
Y = df['y']

# %%
# Membagi data menjadi data latih dan data uji
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
scaler = MinMaxScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
# Pemilihan Fitur
selector = SelectKBest(score_func=chi2, k=11)  # Memilih 5 fitur terbaik
scaled_X_train = selector.fit_transform(scaled_X_train, Y_train)
scaled_X_test = selector.transform(scaled_X_test)

# %%
selector.get_feature_names_out()
# Out:
# array(['x1', 'x2', 'x3', 'x4', 'x5', 'x7', 'x10', 'x11', 'x12', 'x13',
#        'x14'], dtype=object)

# %% [markdown]
# #### 6.3 Definisi Model

# %%
# Inisialisasi model

logreg_model = LogisticRegression()
knn_model = KNeighborsClassifier()
svm_model = SVC()
dt_model = DecisionTreeClassifier()
rf_model = RandomForestClassifier()
nb_model = GaussianNB()

# %% [markdown]
# #### 6.4 Evaluasi Model

# %% [markdown]
# a. Logistic Regression

# %%
# Melatih dan mengevaluasi Logistic Regression
logreg_model.fit(scaled_X_train, Y_train)
logreg_pred = logreg_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, logreg_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, logreg_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Logistic Regression")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Logistic Regression")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      7327
#            1       0.64      0.32      0.43       908
#
#     accuracy                           0.91      8235
#    macro avg       0.78      0.65      0.69      8235
# weighted avg       0.89      0.91      0.89      8235
#
# ...
#
# Model: Logistic Regression
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0         7166          161
# Actual 1          619          289

# %% [markdown]
# b. K-Nearest Neighbors (KNN)

# %%
# Melatih dan mengevaluasi K-Nearest Neighbors (KNN)
knn_model.fit(scaled_X_train, Y_train)
knn_pred = knn_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, knn_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, knn_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: K-Nearest Neighbors (KNN)")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - K-Nearest Neighbors (KNN)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      7327
#            1       0.54      0.32      0.40       908
#
#     accuracy                           0.89      8235
#    macro avg       0.73      0.64      0.67      8235
# weighted avg       0.88      0.89      0.88      8235
#
# ...
#
# Model: K-Nearest Neighbors (KNN)
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0         7078          249
# Actual 1          621          287

# %% [markdown]
# c. Support Vector Machine (SVM)

# %%
# Melatih dan mengevaluasi Support Vector Machine (SVM)
svm_model.fit(scaled_X_train, Y_train)
svm_pred = svm_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, svm_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, svm_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Support Vector Machine (SVM)")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Support Vector Machine (SVM)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      7327
#            1       0.64      0.21      0.31       908
#
#     accuracy                           0.90      8235
#    macro avg       0.78      0.60      0.63      8235
# weighted avg       0.88      0.90      0.88      8235
#
# ...
#
# Model: Support Vector Machine (SVM)
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0         7222          105
# Actual 1          720          188

# %% [markdown]
# d. Decision Tree

# %%
# Melatih dan mengevaluasi Decision Tree
dt_model.fit(scaled_X_train, Y_train)
dt_pred = dt_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, dt_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, dt_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Decision Tree")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Decision Tree")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      7327
#            1       0.38      0.39      0.38       908
#
#     accuracy                           0.86      8235
#    macro avg       0.65      0.65      0.65      8235
# weighted avg       0.86      0.86      0.86      8235
#
# ...
#
# Model: Decision Tree
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0         6754          573
# Actual 1          556          352

# %% [markdown]
# e. Random Forest

# %%
# Melatih dan mengevaluasi Random Forest
rf_model.fit(scaled_X_train, Y_train)
rf_pred = rf_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, rf_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, rf_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Random Forest")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94      7327
#            1       0.53      0.39      0.45       908
#
#     accuracy                           0.89      8235
#    macro avg       0.73      0.67      0.69      8235
# weighted avg       0.88      0.89      0.89      8235
#
# ...
#
# Model: Random Forest
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0         7015          312
# Actual 1          558          350

# %% [markdown]
# f. Naive Bayes

# %%
# Melatih dan mengevaluasi Naive Bayes
nb_model.fit(scaled_X_train, Y_train)
nb_pred = nb_model.predict(scaled_X_test)

# Membuat Confusion Matrix sebagai DataFrame
conf_matrix = confusion_matrix(Y_test, nb_pred)
conf_matrix_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])

# Menampilkan Classification Report
print("Classification Report:")
print(classification_report(Y_test, nb_pred))
print("======================================================\n")

# Menampilkan Tabel Confusion Matrix
print("Model: Naive Bayes")
print("Confusion Matrix:")
print(conf_matrix_df)

# Menampilkan Tabel Confusion Matrix dengan Heatmap (seaborn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', annot_kws={"size": 16})
plt.title("Confusion Matrix - Naive Bayes")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      7327
#            1       0.42      0.44      0.43       908
#
#     accuracy                           0.87      8235
#    macro avg       0.67      0.68      0.68      8235
# weighted avg       0.87      0.87      0.87      8235
#
# ...
#
# Model: Naive Bayes
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0         6775          552
# Actual 1          512          396

# %% [markdown]
# ### Perbandingan Model

# %%
# Inisialisasi model
models = [
    "Logistic Regression",
    "K-Nearest Neighbors (KNN)",
    "Support Vector Machine (SVM)",
    "Decision Tree",
    "Random Forest",
    "Naive Bayes"
]

# Confusion Matrix
confusion_matrices = [
    confusion_matrix(Y_test, logreg_pred),
    confusion_matrix(Y_test, knn_pred),
    confusion_matrix(Y_test, svm_pred),
    confusion_matrix(Y_test, dt_pred),
    confusion_matrix(Y_test, rf_pred),
    confusion_matrix(Y_test, nb_pred)
]

# Classification Report
classification_reports = [
    classification_report(Y_test, logreg_pred, output_dict=True),
    classification_report(Y_test, knn_pred, output_dict=True),
    classification_report(Y_test, svm_pred, output_dict=True),
    classification_report(Y_test, dt_pred, output_dict=True),
    classification_report(Y_test, rf_pred, output_dict=True),
    classification_report(Y_test, nb_pred, output_dict=True)
]

# Membuat DataFrame
df_results = pd.DataFrame({
    'Model': models,
    'Confusion Matrix': confusion_matrices,
    'Classification Report': classification_reports
})

# Memisahkan metrik-metrik evaluasi
df_results['Precision (0)'] = df_results['Classification Report'].apply(lambda x: x['0']['precision'])
df_results['Precision (1)'] = df_results['Classification Report'].apply(lambda x: x['1']['precision'])
df_results['Recall (0)'] = df_results['Classification Report'].apply(lambda x: x['0']['recall'])
df_results['Recall (1)'] = df_results['Classification Report'].apply(lambda x: x['1']['recall'])
df_results['F1-score (0)'] = df_results['Classification Report'].apply(lambda x: x['0']['f1-score'])
df_results['F1-score (1)'] = df_results['Classification Report'].apply(lambda x: x['1']['f1-score'])

# Menghapus kolom 'Classification Report' yang tidak diperlukan
df_results.drop('Classification Report', axis=1, inplace=True)

# Menampilkan DataFrame
df_results
# Out:
#                           Model           Confusion Matrix  Precision (0)  \
# 0           Logistic Regression  [[7166, 161], [619, 289]]       0.920488
# 1     K-Nearest Neighbors (KNN)  [[7078, 249], [621, 287]]       0.919340
# 2  Support Vector Machine (SVM)  [[7222, 105], [720, 188]]       0.909343
# 3                 Decision Tree  [[6754, 573], [556, 352]]       0.923940
# 4                 Random Forest  [[7015, 312], [558, 350]]       0.926317
# 5                   Naive Bayes  [[6775, 552], [512, 396]]       0.929738
#
#    Precision (1)  Recall (0)  Recall (1)  F1-score (0)  F1-score (1)
# 0       0.642222    0.978026    0.318282      0.948385      0.425626
# 1       0.535448    0.966016    0.316079      0.942100      0.397507
# 2       0.641638    0.985669    0.207048      0.945969      0.313072
# 3       0.380541    0.921796    0.387665      0.922867      0.384070
# 4       0.528701    0.957418    0.385463      0.941611      0.445860
# ...

# %% [markdown]
# <b> Insight : </b> Berdasarkan data, didapatkan model terbaik, yaitu KNN. Hal ini disebabkan
# Model KNN memiliki nilai Precision, Recall, dan F1-score yang seimbang untuk kelas yang relevan ('Yes'). Ini menunjukkan bahwa model ini efektif dalam mengidentifikasi pelanggan yang berpotensi berlangganan, dengan meminimalkan jumlah panggilan yang tidak perlu. Sedangkan model lainnya: Logistic Regression, Decision Tree, Random Forest, dan Naive Bayes juga menunjukkan kinerja yang baik, tetapi tidak seimbang antara Precision dan Recall untuk kelas 'Yes'.
